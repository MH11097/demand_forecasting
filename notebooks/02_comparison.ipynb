# %% [markdown]
# # So sánh model — Favorita (NWRMSLE)
#
# Đọc `result.json` của các model (ARIMA, SARIMAX, Prophet, XGBoost, LSTM) và xếp hạng theo **NWRMSLE** (primary). Chạy `scripts/train.py` / `scripts/compare_cv.py` trước.
#
# > ⏳ Bảng/biểu đồ kết quả: chờ chạy thực nghiệm trên Favorita.

# %%
import sys; sys.path.insert(0, '..')
from src.evaluation.comparison import load_results, comparison_table
results = load_results('../results')
table = comparison_table(results)   # đã sort theo nwrmsle
table
